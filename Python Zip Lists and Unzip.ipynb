# %%
import pandas as pd

# %%
df = pd.DataFrame({'numbers': [1, 2, 3], 'colors': ['red', 'white', 'blue']}, 
                  columns=['numbers', 'colors'])

# %%
test=df['numbers'].tolist()
test
# Out:
# [1, 2, 3]

# %%
A = ['a', 'b', 'c']
B = [1, 2, 3]
C = ['t','e','r']

# %%
t = dict(zip(B,C))
t
# Out:
# {1: 'w', 2: 'e', 3: 'r'}

# %%
Q =zip(A,C,B)
Q=list(Q)

# %%
x,y,z = zip(*Q)

# %%
list(x)
# Out:
# ['a', 'b', 'c']

# %%
y
# Out:
# ('t', 'e', 'r')

# %%
R=zip(df['numbers'].tolist(),df['colors'].tolist())

# %%
B,M=zip(*R)

# %%
B
# Out:
# (1, 2, 3)

# %%
M
# Out:
# ('red', 'white', 'blue')
